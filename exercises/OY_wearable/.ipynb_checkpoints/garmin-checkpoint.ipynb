# %%
import os, sys, datetime

from garminconnect import Garmin

email = os.getenv("EMAIL")
password = os.getenv("PASSWORD")
today = datetime.date.today()

api = Garmin(email, password)
api.login()

heartrates = api.get_heart_rates(f'{today.isoformat()}')
bloodoxy = api.get_spo2_data(f'{today.isoformat()}')
breathing = api.get_respiration_data(f'{today.isoformat()}')
print(heartrates, bloodoxy, breathing)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [4], in <cell line: 12>()
#       9 api = Garmin(email, password)
#      10 api.login()
# ---> 12 heartrates = api.get_heart_rates(f'{today.isoformat()}').heartRateValues
#      13 bloodoxy = api.get_spo2_data(f'{today.isoformat()}').sp02HourlyAverages
#      14 breathing = api.get_respiration_data(f'{today.isoformat()}').respirationValuesArray
#
# AttributeError: 'dict' object has no attribute 'heartRateValues'

# %% [markdown]
# # Align the data by creating a timestamped index dataframe

# %%
import pandas as pd
import matplotlib as mpl
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [31], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 import matplotlib as mpl
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
heartrates['heartRateValues']
# Out:
# [[1678057200000, None],
#  [1678081680000, 90],
#  [1678081800000, 95],
#  [1678081920000, 81],
#  [1678082040000, 65],
#  [1678082160000, 70],
#  [1678082280000, 72],
#  [1678082400000, 77],
#  [1678082520000, 83],
#  [1678082640000, 75],
#  [1678082760000, 71],
#  [1678082880000, 79],
#  [1678083000000, 83],
#  [1678083120000, 76],
#  [1678083240000, 59],
#  [1678083360000, 54],
#  [1678083480000, 55],
#  [1678083600000, 67],
#  [1678083720000, 63],
#  [1678083840000, 65],
#  [1678083960000, 66],
#  [1678084080000, 59],
#  [1678084200000, 73],
#  [1678084320000, 59],
#  [1678084440000, 61],
#  [1678084560000, 61],
#  [1678084680000, 66],
#  [1678084800000, 80],
#  [1678084920000, 56],
#  [1678085040000, 51],
#  [1678085160000, 52],
#  [1678085280000, 53],
#  [1678085400000, 52],
#  [1678085520000, 51],
#  [1678085640000, 52],
#  [1678085760000, 53],
#  [1678085880000, 55],
#  [1678086000000, 54],
#  [1678086120000, 55],
#  [1678086240000, 70],
#  [1678086360000, 61],
#  [1678086480000, 52],
#  [1678086600000, 51],
#  [1678086720000, 53],
#  [1678086840000, 52],
#  [1678086960000, 54],
#  [1678087080000, 54],
#  [1678087200000, 54],
#  [1678087320000, 55],
#  [1678087440000, 61],
#  [1678087560000, 57],
#  [1678087680000, 52],
#  [1678087800000, 53],
#  [1678087920000, 51],
#  [1678088040000, 51],
#  [1678088160000, 52],
#  [1678088280000, 52],
#  [1678088400000, 51],
#  [1678088520000, 52],
#  [1678088640000, 52],
#  [1678088760000, 51],
#  [1678088880000, 51],
#  [1678089000000, 52],
#  [1678089120000, 50],
#  [1678089240000, 50],
#  [1678089360000, 50],
#  [1678089480000, 50],
#  [1678089600000, 50],
#  [1678089720000, 50],
#  [1678089840000, 51],
#  [1678089960000, 52],
#  [1678090080000, 52],
#  [1678090200000, 52],
#  [1678090320000, 51],
#  [1678090440000, 52],
#  [1678090560000, 52],
#  [1678090680000, 52],
#  [1678096560000, 14.0],
#  [1678096680000, 13.0],
#  [1678096800000, 13.0],
#  [1678096920000, 12.0],
#  [1678097040000, 13.0],
#  [1678097160000, 13.0],
#  [1678097280000, 13.0],
#  [1678097400000, 12.0],
#  [1678097520000, 11.0],
#  [1678097640000, 11.0],
#  [1678097760000, 11.0],
#  [1678097880000, 11.0],
#  [1678098000000, 11.0],
#  [1678098120000, 12.0],
#  [1678098240000, 14.0],
#  [1678098360000, 12.0],
#  [1678098480000, 14.0],
#  [1678098600000, 15.0],
#  [1678098720000, 13.0],
#  [1678098840000, 12.0],
#  [1678098960000, 12.0],
#  [1678099080000, 12.0],
#  [1678099200000, 14.0],
#  [1678099320000, 13.0],
#  [1678099440000, 14.0],
#  [1678099560000, 14.0]]

# %%
columns = {
    'breathing': breathing['respirationValuesArray'],
    'bloodoxy': bloodoxy['spO2HourlyAverages'],
    'heartrate': heartrates['heartRateValues']
}

dicts = {}
for i, column in columns.items():
    dicts[i] = {item[0]: item[1] for item in column}

df = pd.DataFrame.from_dict(dicts, orient='columns')
df
# Out:
#                breathing  bloodoxy  heartrate
# 1678057320000       -1.0       NaN        NaN
# 1678057440000       -1.0       NaN        NaN
# 1678057560000       -1.0       NaN        NaN
# 1678057680000       -1.0       NaN        NaN
# 1678057800000       -1.0       NaN        NaN
# ...                  ...       ...        ...
# 1678099200000       14.0       NaN       50.0
# 1678099320000       13.0       NaN       48.0
# 1678099440000       14.0       NaN       49.0
# 1678099560000       14.0       NaN        NaN
# 1678057200000        NaN       NaN        NaN
#
# [354 rows x 3 columns]

# %%
df.plot()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 df.plot()
#
# File /nix/store/4z4amdln6pqh9drdbmhqn9ap0gvicfyg-python3.10-pandas-1.5.2/lib/python3.10/site-packages/pandas/plotting/_core.py:920, in PlotAccessor.__call__(self, *args, **kwargs)
#     919 def __call__(self, *args, **kwargs):
# --> 920     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     922     x, y, kind, kwargs = self._get_call_args(
#     923         plot_backend.__name__, self._parent, args, kwargs
#     924     )
#     926     kind = self._kind_aliases.get(kind, kind)
#
# File /nix/store/4z4amdln6pqh9drdbmhqn9ap0gvicfyg-python3.10-pandas-1.5.2/lib/python3.10/site-packages/pandas/plotting/_core.py:1898, in _get_plot_backend(backend)
#    1895 if backend_str in _backends:
#    1896     return _backends[backend_str]
# -> 1898 module = _load_backend(backend_str)
#    1899 _backends[backend_str] = module
#    1900 return module
#
# File /nix/store/4z4amdln6pqh9drdbmhqn9ap0gvicfyg-python3.10-pandas-1.5.2/lib/python3.10/site-packages/pandas/plotting/_core.py:1829, in _load_backend(backend)
#    1827         module = importlib.import_module("pandas.plotting._matplotlib")
#    1828     except ImportError:
# -> 1829         raise ImportError(
#    1830             "matplotlib is required for plotting when the "
#    1831             'default backend "matplotlib" is selected.'
#    1832         ) from None
#    1833     return module
#    1835 found_backend = False
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
